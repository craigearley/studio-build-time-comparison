# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
filename = 'android-studio-data.csv'
studio_data = pd.read_csv(filename,header=None)
studio_data = studio_data.rename(columns={0:"app",1:"laptop",2:"step",3:"time"})
studio_data['app'] = studio_data['app'].replace({"fieldday":"Field Day","majortom":"Major Tom"})
studio_data
# Out:
#           app laptop                    step     time
# 0   Field Day    old     synced successfully  64.736s
# 1   Field Day    old  completed successfully   4.705s
# 2   Field Day    old       build and install      NaN
# 3   Major Tom    old     synced successfully  61.274s
# 4   Major Tom    old  completed successfully   2.674s
# 5   Major Tom    old       build and install      NaN
# 6   Field Day    new     synced successfully  15.363s
# 7   Field Day    new  completed successfully   1.368s
# 8   Field Day    new       build and install      NaN
# 9   Major Tom    new     synced successfully  14.375s
# 10  Major Tom    new  completed successfully   1.358s
# 11  Major Tom    new       build and install      NaN
